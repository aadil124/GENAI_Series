# %%
### Load Env Variables

from dotenv import load_dotenv
load_dotenv()

# using open ai
# from langchain_openai import ChatOpenAI
# llm = ChatOpenAI(model="gpt-4o")

# res=llm.invoke("who is pm of india")


# print(res.content)



# using google gemini
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
res = llm.invoke("what is llm?")

print(res.content)


# using Antropic claude


# from langchain_anthropic import ChatAnthropic
# llm = ChatAnthropic(model="claude-3-sonnet-20240229")

# res = llm.invoke("What is the best course in India?")

# print(res.content)
# Out:
# An **LLM** stands for **Large Language Model**.
#
# It's a type of artificial intelligence (AI) program that has been trained on a massive amount of text data to understand, generate, and process human language.
#
# Here's a breakdown of what that means:
#
# 1.  **Large:**
#     *   **Data:** LLMs are trained on enormous datasets, often comprising text from the entire internet (books, articles, websites, conversations, code, etc.). This can be trillions of words.
#     *   **Parameters:** They have billions, sometimes hundreds of billions, or even trillions of "parameters." These are the internal variables that the model adjusts during training to learn patterns and relationships in the language. More parameters generally mean a more complex and capable model.
#
# 2.  **Language:**
#     *   Their primary function revolves around human language. They learn grammar, syntax, semantics, context, facts, reasoning patterns, and even different writing styles.
#
# 3.  **Model:**
#     *   It's a sophisticated computer program, typically based on a neural network architecture called a "Transformer."
#     *   During training, the model learns to predict the next word in a sequence. By doing this repeatedly across vast amounts of text, it develops a deep understanding of how language works and how concepts relate to each other.
#
# **How LLMs Work (Simplified):**
#
# Imagine giving a student every book, article, and piece of writing ever created, and then asking them to constantly predict the next word in any given sentence. Over time, that student would become incredibly good at understanding context, grammar, and even the nuances of different topics.
#
# LLMs do something similar. They don't "understand" in the human sense, but they become highly skilled at identifying statistical patterns and relationships between words and concepts. When you give an LLM a prompt, it uses these learned patterns to generate a statistically probable and coherent response, word by word.
#
# **Key Capabilities:**
#
# *   **Text Generation:** Writing articles, stories, poems, code, emails, marketing copy.
# *   **Summarization:** Condensing long texts into shorter versions.
# *   **Translation:** Converting text from one language to another.
# *   **Question Answering:** Providing information based on its training data.
# *   **Conversation:** Engaging in human-like dialogue (like ChatGPT).
# *   **Code Generation:** Writing or debugging programming code.
# *   **Brainstorming & Idea Generation:** Helping users explore different concepts.
#
# **Examples of LLMs and LLM-powered applications:**
#
# *   **ChatGPT** (from OpenAI)
# *   **Gemini** (from Google)
# *   **Claude** (from Anthropic)
# *   **Llama** (from Meta)
#
# In essence, LLMs are powerful AI systems designed to process and generate human-like text, making them incredibly versatile tools for a wide range of applications.
