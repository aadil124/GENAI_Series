# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain.agents import create_agent
search = GoogleSerperAPIWrapper()

load_dotenv()

llm=ChatGroq(model="openai/gpt-oss-20b")

agent = create_agent(
    model=llm,
    tools=[search.run],
    system_prompt="your are a agent you can sreach any question on google"
)
# question = "What is the best Gen AI / Agentic AI series on Youtube"/
question = "Who won T20 World cup in 2024 and 2026"
response=agent.invoke({"messages":[{"role":"user","content":question}]}) 
print(response["messages"][-1].content)
# Out:
# - **ICC Men's T20 World Cup 2024** – **India** (defeated South Africa in the final)
# - **ICC Men's T20 World Cup 2026** – **India** (defeated New Zealand in the final)
